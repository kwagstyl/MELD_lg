# %%
import pandas as pd
import numpy as np

# %%
#load in text file from data directory
df=np.loadtxt('../data/all_patients_nsubs_n-normalised.txt')
df=pd.DataFrame(df)
df.columns=['ROI_code','lesion_frequency']

# %%
df
# Out:
#      ROI_code  lesion_frequency
# 0         0.0              0.00
# 1         1.0              1.02
# 2         2.0              1.30
# 3         3.0              0.81
# 4         4.0              0.99
# 5         5.0              0.95
# 6         6.0              1.04
# 7         7.0              1.44
# 8         8.0              1.59
# 9         9.0              1.21
# 10       10.0              2.55
# 11       11.0              1.86
# 12       12.0              2.12
# 13       13.0              0.91
# 14       14.0              0.32
# 15       15.0              0.32
# 16       16.0              1.10
# 17       17.0              0.91
# 18       18.0              1.74
# 19       19.0              0.87
# 20       20.0              1.29
# 21       21.0              1.15
# 22       22.0              1.25
# 23       23.0              1.18
# 24       24.0              1.93
# 25       25.0              2.38
# 26       26.0              2.29
# 27       27.0              0.81
# ...
